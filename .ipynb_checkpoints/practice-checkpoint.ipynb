# %%
import numpy as np

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ar = np.array([4,5,3,2,7,8,5,4,3])

# %%
np.sum(ar)/len(ar)
# Out:
# np.float64(4.555555555555555)

# %%
len(ar)
# Out:
# 9

# %%
np.sort(ar)
# Out:
# array([2, 3, 3, 4, 4, 5, 5, 7, 8])

# %%
np.mean(ar)
# Out:
# np.float64(4.555555555555555)

# %%
dataset = pd.read_csv("solarpowergeneration.csv")
dataset.head(3)
# Out:
#    distance-to-solar-noon  temperature  wind-direction  wind-speed  sky-cover  \
# 0                0.859897           69              28         7.5          0
# 1                0.628535           69              28         7.5          0
# 2                0.397172           69              28         7.5          0
#
#    visibility  humidity  average-wind-speed-(period)  \
# 0        10.0        75                          8.0
# 1        10.0        77                          5.0
# 2        10.0        70                          0.0
#
#    average-pressure-(period)  power-generated
# 0                      29.82                0
# 1                      29.85                0
# 2                      29.89             5418

# %%
dataset.head(10)
# Out:
#    distance-to-solar-noon  temperature  wind-direction  wind-speed  sky-cover  \
# 0                0.859897           69              28         7.5          0
# 1                0.628535           69              28         7.5          0
# 2                0.397172           69              28         7.5          0
# 3                0.165810           69              28         7.5          0
# 4                0.065553           69              28         7.5          0
# 5                0.296915           69              28         7.5          0
# 6                0.528278           69              28         7.5          0
# 7                0.759640           69              28         7.5          0
# 8                0.862113           72              29         6.8          0
# 9                0.630155           72              29         6.8          0
#
#    visibility  humidity  average-wind-speed-(period)  \
# 0        10.0        75                          8.0
# ...

# %%
dataset["temperature"].mean()
# Out:
# np.float64(58.46849315068493)

# %%
np.mean(dataset["power-generated"])
# Out:
# np.float64(6979.846232876713)

# %%
mn = np.mean(dataset["temperature"])

# %%
sns.histplot(x="temperature", data=dataset,bins=[i for i in range(30,100,10)])
plt.plot([mn for i in range(0,100)], [i for i in range(0,100)],c="red")
plt.show()
